# %% [markdown]
# # Transfer Trajectory: UKR+COVID+Midterm NM Aug
#
# Visualizes transfer evals for `merged_ukr_rus_covid_midterm_nm_aug_15_06_2026_17_49_22` at checkpoints 1k, 10k, 50k, and 100k.

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

sns.set_theme(style="whitegrid", context="notebook")

NOTEBOOK_DIR = Path("scripts/plotting/transfer_trajectory_merged_ukr_rus_covid_midterm_nm_aug")
CSV_NAME = "eval_results_transfer_trajectory_merged_ukr_rus_covid_midterm_nm_aug.csv"
CSV_PATH = Path(CSV_NAME)
if not CSV_PATH.exists():
    CSV_PATH = NOTEBOOK_DIR / CSV_NAME
CSV_PATH = CSV_PATH.resolve()

SPLIT = "test"
METRIC = "roc_auc"
METRICS = ["accuracy", "f1", "roc_auc"]
REQUESTED_STEPS = [1000, 10000, 50000, 100000]
SHOT_ORDER = [0, 3, 10]
DATASET_ORDER = [
    "midterm",
    "covid19_twitter",
    "ukr_rus_twitter",
    "covid_political",
    "election2020",
    "ukr_rus_suspended",
]
TASK_ORDER = ["nm", "lp", "pl"]
TASK_LABELS = {
    "nm": "Neighbor matching",
    "lp": "Temporal link prediction",
    "pl": "Classification",
}
METRIC_LABELS = {
    "accuracy": "Accuracy",
    "f1": "F1",
    "roc_auc": "ROC-AUC",
}
FIG_DIR = CSV_PATH.parent / "figures"
FIG_DIR.mkdir(exist_ok=True)

# %%
df = pd.read_csv(CSV_PATH)
required = {"model", "dataset", "task", "shots", "split", *METRICS}
missing = required - set(df.columns)
if missing:
    raise ValueError(f"CSV is missing required columns: {sorted(missing)}")

df["shots"] = pd.to_numeric(df["shots"], errors="raise").astype(int)
for col in METRICS:
    df[col] = pd.to_numeric(df[col], errors="coerce")

df["step"] = df["model"].str.extract(r"_step([0-9]+)$", expand=False)
if df["step"].isna().any():
    bad = df.loc[df["step"].isna(), "model"].tolist()
    raise ValueError(f"Could not parse checkpoint step from model names: {bad}")
df["step"] = df["step"].astype(int)

df = df[(df["split"] == SPLIT) & (df["step"].isin(REQUESTED_STEPS))].copy()
df["dataset"] = pd.Categorical(df["dataset"], categories=DATASET_ORDER, ordered=True)
df["task"] = pd.Categorical(df["task"], categories=TASK_ORDER, ordered=True)
df["shots"] = pd.Categorical(df["shots"], categories=SHOT_ORDER, ordered=True)
df = df.sort_values(["dataset", "task", "shots", "step"])

present_steps = sorted(df["step"].dropna().unique().tolist())
missing_steps = sorted(set(REQUESTED_STEPS) - set(present_steps))
print(f"reading {CSV_PATH}")
print(f"rows: {len(df)}")
print(f"present steps: {present_steps}")
print(f"missing requested steps: {missing_steps}")

def join_ints(values):
    return ", ".join(str(v) for v in sorted(set(int(v) for v in values.dropna())))

coverage = (
    df.groupby(["dataset", "task"], observed=True)
      .agg(
          shots=("shots", join_ints),
          steps=("step", join_ints),
          rows=("step", "size"),
      )
      .reset_index()
      .sort_values(["dataset", "task"])
)
display(coverage)
# Out:
# reading /Users/philipp/projects/gfm/prodigy/scripts/plotting/transfer_trajectory_merged_ukr_rus_covid_midterm_nm_aug/eval_results_transfer_trajectory_merged_ukr_rus_covid_midterm_nm_aug.csv
# rows: 144
# present steps: [1000, 10000, 50000, 100000]
# missing requested steps: []
#               dataset task     shots                       steps  rows
# 0             midterm   nm  0, 3, 10  1000, 10000, 50000, 100000    12
# 1             midterm   lp  0, 3, 10  1000, 10000, 50000, 100000    12
# 2     covid19_twitter   nm  0, 3, 10  1000, 10000, 50000, 100000    12
# 3     covid19_twitter   lp  0, 3, 10  1000, 10000, 50000, 100000    12
# 4     ukr_rus_twitter   nm  0, 3, 10  1000, 10000, 50000, 100000    12
# 5     ukr_rus_twitter   lp  0, 3, 10  1000, 10000, 50000, 100000    12
# 6     covid_political   nm  0, 3, 10  1000, 10000, 50000, 100000    12
# 7     covid_political   pl  0, 3, 10  1000, 10000, 50000, 100000    12
# 8        election2020   nm  0, 3, 10  1000, 10000, 50000, 100000    12
# 9        election2020   pl  0, 3, 10  1000, 10000, 50000, 100000    12
# 10  ukr_rus_suspended   nm  0, 3, 10  1000, 10000, 50000, 100000    12
# 11  ukr_rus_suspended   pl  0, 3, 10  1000, 10000, 50000, 100000    12

# %%
def plot_metric_grid(data, metric=METRIC):
    subset = data[data[metric].notna()].copy()
    if subset.empty:
        raise ValueError(f"No non-null values for metric={metric!r}")

    datasets = [d for d in DATASET_ORDER if d in set(subset["dataset"].astype(str))]
    tasks = [t for t in TASK_ORDER if t in set(subset["task"].astype(str))]
    palette = dict(zip(REQUESTED_STEPS, sns.color_palette("Set2", n_colors=len(REQUESTED_STEPS))))

    fig, axes = plt.subplots(
        nrows=len(datasets),
        ncols=len(tasks),
        figsize=(4.7 * len(tasks), 2.5 * len(datasets)),
        sharex=True,
        sharey=True,
    )
    if len(datasets) == 1 and len(tasks) == 1:
        axes = [[axes]]
    elif len(datasets) == 1:
        axes = [axes]
    elif len(tasks) == 1:
        axes = [[ax] for ax in axes]

    for row_idx, dataset in enumerate(datasets):
        for col_idx, task in enumerate(tasks):
            ax = axes[row_idx][col_idx]
            panel = subset[(subset["dataset"].astype(str) == dataset) & (subset["task"].astype(str) == task)]
            ax.set_title(f"{dataset}\n{TASK_LABELS.get(task, task)}", fontsize=10)
            if panel.empty:
                ax.text(0.5, 0.5, "no data", transform=ax.transAxes, ha="center", va="center", color="0.45")
            else:
                for step in REQUESTED_STEPS:
                    line = panel[panel["step"] == step].sort_values("shots")
                    if line.empty:
                        continue
                    ax.plot(
                        line["shots"].astype(int),
                        line[metric],
                        marker="o",
                        linewidth=2,
                        markersize=4,
                        color=palette[step],
                        label=f"{step // 1000}k",
                    )
            ax.set_xticks(SHOT_ORDER)
            ax.set_xticklabels([f"{shot}-shot" for shot in SHOT_ORDER])
            ax.set_ylim(0, 1.02)
            ax.grid(True, alpha=0.3)
            if row_idx == len(datasets) - 1:
                ax.set_xlabel("shots")
            if col_idx == 0:
                ax.set_ylabel(METRIC_LABELS.get(metric, metric))

    handles, labels = axes[0][0].get_legend_handles_labels()
    if handles:
        fig.legend(handles, labels, title="checkpoint", loc="upper center", ncol=len(labels), bbox_to_anchor=(0.5, 1.02))
    fig.suptitle(f"Transfer by shots and checkpoint - {METRIC_LABELS.get(metric, metric)}", y=1.04, fontsize=14)
    fig.tight_layout()
    out_path = FIG_DIR / f"transfer_trajectory_{metric}.png"
    fig.savefig(out_path, dpi=200, bbox_inches="tight")
    return fig

# plot_metric_grid(df, METRIC)
# plt.show()

# %%
plot_metric_grid(df, 'roc_auc')
plt.show()

# %%
t = df[df.shots.eq(3) & df.step.eq(10_000)].drop_duplicates(["checkpoint", 'dataset', 'task'])[["dataset", "task", "roc_auc"]]
t['train_id'] = 'merged_ukr_covid_midterm_aug'
t.to_csv()
# Out:
# ',dataset,task,roc_auc,train_id\n58,midterm,nm,0.9128661273148148,merged_ukr_covid_midterm_aug\n55,midterm,lp,0.7175522916666667,merged_ukr_covid_midterm_aug\n40,covid19_twitter,nm,0.9868899606481482,merged_ukr_covid_midterm_aug\n37,covid19_twitter,lp,0.7812732499999999,merged_ukr_covid_midterm_aug\n70,ukr_rus_twitter,nm,0.9445974212962964,merged_ukr_covid_midterm_aug\n67,ukr_rus_twitter,lp,0.8079841944444446,merged_ukr_covid_midterm_aug\n43,covid_political,nm,0.8856009027777777,merged_ukr_covid_midterm_aug\n46,covid_political,pl,0.8706933888888888,merged_ukr_covid_midterm_aug\n49,election2020,nm,0.8714116666666666,merged_ukr_covid_midterm_aug\n52,election2020,pl,0.9774,merged_ukr_covid_midterm_aug\n61,ukr_rus_suspended,nm,0.810928,merged_ukr_covid_midterm_aug\n64,ukr_rus_suspended,pl,0.5372399999999999,merged_ukr_covid_midterm_aug\n'

# %%
best_rows = []
for metric in METRICS:
    valid = df[df[metric].notna()]
    if valid.empty:
        continue
    idx = valid.groupby(["dataset", "task", "shots"], observed=True)[metric].idxmax()
    best = valid.loc[idx, ["dataset", "task", "shots", "step", metric]].copy()
    best["metric"] = metric
    best = best.rename(columns={metric: "value", "step": "best_step"})
    best_rows.append(best)

best_table = pd.concat(best_rows, ignore_index=True) if best_rows else pd.DataFrame()
best_table["metric_label"] = best_table["metric"].map(METRIC_LABELS)
best_table = best_table.sort_values(["dataset", "task", "shots", "metric"])
display(best_table[["dataset", "task", "shots", "metric_label", "best_step", "value"]].style.format({"value": "{:.4f}"}))
# Out:
# <style type="text/css">
# </style>
# <table id="T_fe0b2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe0b2_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_fe0b2_level0_col1" class="col_heading level0 col1" >task</th>
#       <th id="T_fe0b2_level0_col2" class="col_heading level0 col2" >shots</th>
#       <th id="T_fe0b2_level0_col3" class="col_heading level0 col3" >metric_label</th>
#       <th id="T_fe0b2_level0_col4" class="col_heading level0 col4" >best_step</th>
#       <th id="T_fe0b2_level0_col5" class="col_heading level0 col5" >value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe0b2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fe0b2_row0_col0" class="data row0 col0" >midterm</td>
#       <td id="T_fe0b2_row0_col1" class="data row0 col1" >nm</td>
#       <td id="T_fe0b2_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_fe0b2_row0_col3" class="data row0 col3" >Accuracy</td>
#       <td id="T_fe0b2_row0_col4" class="data row0 col4" >10000</td>
#       <td id="T_fe0b2_row0_col5" class="data row0 col5" >0.3323</td>
#     </tr>
#     <tr>
#       <th id="T_fe0b2_level0_row1" class="row_heading level0 row1" >36</th>
#       <td id="T_fe0b2_row1_col0" class="data row1 col0" >midterm</td>
#       <td id="T_fe0b2_row1_col1" class="data row1 col1" >nm</td>
#       <td id="T_fe0b2_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_fe0b2_row1_col3" class="data row1 col3" >F1</td>
#       <td id="T_fe0b2_row1_col4" class="data row1 col4" >100000</td>
#       <td id="T_fe0b2_row1_col5" class="data row1 col5" >0.2926</td>
#     </tr>
#     <tr>
#       <th id="T_fe0b2_level0_row2" class="row_heading level0 row2" >72</th>
#       <td id="T_fe0b2_row2_col0" class="data row2 col0" >midterm</td>
#       <td id="T_fe0b2_row2_col1" class="data row2 col1" >nm</td>
#       <td id="T_fe0b2_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_fe0b2_row2_col3" class="data row2 col3" >ROC-AUC</td>
#       <td id="T_fe0b2_row2_col4" class="data row2 col4" >100000</td>
#       <td id="T_fe0b2_row2_col5" class="data row2 col5" >0.4974</td>
#     </tr>
#     <tr>
#       <th id="T_fe0b2_level0_row3" class="row_heading level0 row3" >1</th>
#       <td id="T_fe0b2_row3_col0" class="data row3 col0" >midterm</td>
#       <td id="T_fe0b2_row3_col1" class="data row3 col1" >nm</td>
#       <td id="T_fe0b2_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_fe0b2_row3_col3" class="data row3 col3" >Accuracy</td>
#       <td id="T_fe0b2_row3_col4" class="data row3 col4" >100000</td>
#       <td id="T_fe0b2_row3_col5" class="data row3 col5" >0.7527</td>
#     </tr>
#     <tr>
#       <th id="T_fe0b2_level0_row4" class="row_heading level0 row4" >37</th>
#       <td id="T_fe0b2_row4_col0" class="data row4 col0" >midterm</td>
#       <td id="T_fe0b2_row4_col1" class="data row4 col1" >nm</td>
#       <td id="T_fe0b2_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_fe0b2_row4_col3" class="data row4 col3" >F1</td>
#       <td id="T_fe0b2_row4_col4" class="data row4 col4" >100000</td>
#       <td id="T_fe0b2_row4_col5" class="data row4 col5" >0.7527</td>
#     </tr>
#     <tr>
#       <th id="T_fe0b2_level0_row5" class="row_heading level0 row5" >73</th>
#       <td id="T_fe0b2_row5_col0" class="data row5 col0" >midterm</td>
#       <td id="T_fe0b2_row5_col1" class="data row5 col1" >nm</td>
#       <td id="T_fe0b2_row5_col2" class="data row5 col2" >3</td>
#       <td id="T_fe0b2_row5_col3" class="data row5 col3" >ROC-AUC</td>
#       <td id="T_fe0b2_row5_col4" class="data row5 col4" >100000</td>
#       <td id="T_fe0b2_row5_col5" class="data row5 col5" >0.9240</td>
#     </tr>
#     <tr>
#       <th id="T_fe0b2_level0_row6" class="row_heading level0 row6" >2</th>
#       <td id="T_fe0b2_row6_col0" class="data row6 col0" >midterm</td>
#       <td id="T_fe0b2_row6_col1" class="data row6 col1" >nm</td>
#       <td id="T_fe0b2_row6_col2" class="data row6 col2" >10</td>
#       <td id="T_fe0b2_row6_col3" class="data row6 col3" >Accuracy</td>
#       <td id="T_fe0b2_row6_col4" class="data row6 col4" >100000</td>
#       <td id="T_fe0b2_row6_col5" class="data row6 col5" >0.7879</td>
#     </tr>
#     <tr>
#       <th id="T_fe0b2_level0_row7" class="row_heading level0 row7" >38</th>
#       <td id="T_fe0b2_row7_col0" class="data row7 col0" >midterm</td>
#       <td id="T_fe0b2_row7_col1" class="data row7 col1" >nm</td>
#       <td id="T_fe0b2_row7_col2" class="data row7 col2" >10</td>
#       <td id="T_fe0b2_row7_col3" class="data row7 col3" >F1</td>
#       <td id="T_fe0b2_row7_col4" class="data row7 col4" >100000</td>
#       <td id="T_fe0b2_row7_col5" class="data row7 col5" >0.7879</td>
#     </tr>
#     <tr>
#       <th id="T_fe0b2_level0_row8" class="row_heading level0 row8" >74</th>
#       <td id="T_fe0b2_row8_col0" class="data row8 col0" >midterm</td>
#       <td id="T_fe0b2_row8_col1" class="data row8 col1" >nm</td>
#       <td id="T_fe0b2_row8_col2" class="data row8 col2" >10</td>
#       <td id="T_fe0b2_row8_col3" class="data row8 col3" >ROC-AUC</td>
#       <td id="T_fe0b2_row8_col4" class="data row8 col4" >100000</td>
#       <td id="T_fe0b2_row8_col5" class="data row8 col5" >0.9449</td>
#     </tr>
#     <tr>
#       <th id="T_fe0b2_level0_row9" class="row_heading level0 row9" >3</th>
#       <td id="T_fe0b2_row9_col0" class="data row9 col0" >midterm</td>
#       <td id="T_fe0b2_row9_col1" class="data row9 col1" >lp</td>
#       <td id="T_fe0b2_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_fe0b2_row9_col3" class="data row9 col3" >Accuracy</td>
#       <td id="T_fe0b2_row9_col4" class="data row9 col4" >1000</td>
#       <td id="T_fe0b2_row9_col5" class="data row9 col5" >0.5539</td>
#     </tr>
#     <tr>
#       <th id="T_fe0b2_level0_row10" class="row_heading level0 row10" >39</th>
#       <td id="T_fe0b2_row10_col0" class="data row10 col0" >midterm</td>
#       <td id="T_fe0b2_row10_col1" class="data row10 col1" >lp</td>
#       <td id="T_fe0b2_row10_col2" class="data row10 col2" >0</td>
#       <td id="T_fe0b2_row10_col3" class="data row10 col3" >F1</td>
#       <td id="T_fe0b2_row10_col4" class="data row10 col4" >1000</td>
#       <td id="T_fe0b2_row10_col5" class="data row10 col5" >0.4880</td>
#     </tr>
#     <tr>
#       <th id="T_fe0b2_level0_row11" class="row_heading level0 row11" >75</th>
#       <td id="T_fe0b2_row11_col0" class="data row11 col0" >midterm</td>
#       <td id="T_fe0b2_row11_col1" class="data row11 col1" >lp</td>
#       <td id="T_fe0b2_row11_col2" class="data row11 col2" >0</td>
#       <td id="T_fe0b2_row11_col3" class="data row11 col3" >ROC-AUC</td>
#       <td id="T_fe0b2_row11_col4" class="data row11 col4" >1000</td>
#       <td id="T_fe0b2_row11_col5" class="data row11 col5" >0.5819</td>
#     </tr>
#     <tr>
#       <th id="T_fe0b2_level0_row12" class="row_heading level0 row12" >4</th>
#       <td id="T_fe0b2_row12_col0" class="data row12 col0" >midterm</td>
#       <td id="T_fe0b2_row12_col1" class="data row12 col1" >lp</td>
#       <td id="T_fe0b2_row12_col2" class="data row12 col2" >3</td>
#       <td id="T_fe0b2_row12_col3" class="data row12 col3" >Accuracy</td>
#       <td id="T_fe0b2_row12_col4" class="data row12 col4" >10000</td>
#       <td id="T_fe0b2_row12_col5" class="data row12 col5" >0.6302</td>
#     </tr>
#     <tr>
#       <th id="T_fe0b2_level0_row13" class="row_heading level0 row13" >40</th>
#       <td id="T_fe0b2_row13_col0" class="data row13 col0" >midterm</td>
#       <td id="T_fe0b2_row13_col1" class="data row13 col1" >lp</td>
#       <td id="T_fe0b2_row13_col2" class="data row13 col2" >3</td>
#       <td id="T_fe0b2_row13_col3" class="data row13 col3" >F1</td>
#       <td id="T_fe0b2_row13_col4" class="data row13 col4" >100000</td>
#       <td id="T_fe0b2_row13_col5" class="data row13 col5" >0.7105</td>
#     </tr>
#     <tr>
#       <th id="T_fe0b2_level0_row14" class="row_heading level0 row14" >76</th>
#       <td id="T_fe0b2_row14_col0" class="data row14 col0" >midterm</td>
#       <td id="T_fe0b2_row14_col1" class="data row14 col1" >lp</td>
#       <td id="T_fe0b2_row14_col2" class="data row14 col2" >3</td>
#       <td id="T_fe0b

# %%
wide = (
    df.pivot_table(
        index=["dataset", "task", "shots"],
        columns="step",
        values=METRIC,
        observed=True,
    )
    .reindex(columns=REQUESTED_STEPS)
    .sort_index()
)
display(wide.style.format("{:.4f}").background_gradient(cmap="YlGnBu", axis=1))
# Out:
# <style type="text/css">
# #T_94b51_row0_col0, #T_94b51_row1_col0, #T_94b51_row2_col0, #T_94b51_row3_col3, #T_94b51_row4_col0, #T_94b51_row5_col0, #T_94b51_row6_col0, #T_94b51_row7_col0, #T_94b51_row8_col0, #T_94b51_row9_col3, #T_94b51_row10_col0, #T_94b51_row11_col0, #T_94b51_row12_col3, #T_94b51_row13_col0, #T_94b51_row14_col0, #T_94b51_row15_col3, #T_94b51_row16_col0, #T_94b51_row17_col0, #T_94b51_row18_col0, #T_94b51_row19_col0, #T_94b51_row20_col0, #T_94b51_row21_col0, #T_94b51_row22_col0, #T_94b51_row23_col0, #T_94b51_row24_col3, #T_94b51_row25_col0, #T_94b51_row26_col0, #T_94b51_row27_col0, #T_94b51_row28_col1, #T_94b51_row29_col0, #T_94b51_row30_col3, #T_94b51_row31_col0, #T_94b51_row32_col0, #T_94b51_row33_col2, #T_94b51_row34_col0, #T_94b51_row35_col0 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_94b51_row0_col1 {
#   background-color: #4ebbc2;
#   color: #000000;
# }
# #T_94b51_row0_col2, #T_94b51_row8_col2 {
#   background-color: #142670;
#   color: #f1f1f1;
# }
# #T_94b51_row0_col3, #T_94b51_row1_col3, #T_94b51_row2_col3, #T_94b51_row3_col0, #T_94b51_row4_col2, #T_94b51_row4_col3, #T_94b51_row5_col3, #T_94b51_row6_col3, #T_94b51_row7_col3, #T_94b51_row8_col3, #T_94b51_row9_col0, #T_94b51_row10_col3, #T_94b51_row11_col3, #T_94b51_row12_col0, #T_94b51_row13_col3, #T_94b51_row14_col3, #T_94b51_row15_col1, #T_94b51_row16_col3, #T_94b51_row17_col3, #T_94b51_row18_col1, #T_94b51_row19_col3, #T_94b51_row20_col2, #T_94b51_row21_col3, #T_94b51_row22_col3, #T_94b51_row23_col2, #T_94b51_row24_col0, #T_94b51_row25_col2, #T_94b51_row26_col2, #T_94b51_row27_col3, #T_94b51_row28_col0, #T_94b51_row29_col1, #T_94b51_row30_col1, #T_94b51_row30_col2, #T_94b51_row31_col3, #T_94b51_row32_col3, #T_94b51_row33_col3, #T_94b51_row34_col1, #T_94b51_row35_col3 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_94b51_row1_col1 {
#   background-color: #2166ac;
#   color: #f1f1f1;
# }
# #T_94b51_row1_col2 {
#   background-color: #234c9f;
#   color: #f1f1f1;
# }
# #T_94b51_row2_col1 {
#   background-color: #2258a5;
#   color: #f1f1f1;
# }
# #T_94b51_row2_col2 {
#   background-color: #253595;
#   color: #f1f1f1;
# }
# #T_94b51_row3_col1 {
#   background-color: #2259a6;
#   color: #f1f1f1;
# }
# #T_94b51_row3_col2 {
#   background-color: #75c9bd;
#   color: #000000;
# }
# #T_94b51_row4_col1 {
#   background-color: #2da2c2;
#   color: #f1f1f1;
# }
# #T_94b51_row5_col1 {
#   background-color: #3eb3c4;
#   color: #f1f1f1;
# }
# #T_94b51_row5_col2 {
#   background-color: #0b1f5e;
#   color: #f1f1f1;
# }
# #T_94b51_row6_col1 {
#   background-color: #2073b2;
#   color: #f1f1f1;
# }
# #T_94b51_row6_col2 {
#   background-color: #225aa6;
#   color: #f1f1f1;
# }
# #T_94b51_row7_col1, #T_94b51_row20_col3 {
#   background-color: #24459c;
#   color: #f1f1f1;
# }
# #T_94b51_row7_col2 {
#   background-color: #172978;
#   color: #f1f1f1;
# }
# #T_94b51_row8_col1, #T_94b51_row17_col2 {
#   background-color: #24479d;
#   color: #f1f1f1;
# }
# #T_94b51_row9_col1, #T_94b51_row14_col2 {
#   background-color: #1e2e85;
#   color: #f1f1f1;
# }
# #T_94b51_row9_col2 {
#   background-color: #4ab9c3;
#   color: #f1f1f1;
# }
# #T_94b51_row10_col1 {
#   background-color: #3aaec3;
#   color: #f1f1f1;
# }
# #T_94b51_row10_col2 {
#   background-color: #0d2161;
#   color: #f1f1f1;
# }
# #T_94b51_row11_col1 {
#   background-color: #39adc3;
#   color: #f1f1f1;
# }
# #T_94b51_row11_col2 {
#   background-color: #0a1e5c;
#   color: #f1f1f1;
# }
# #T_94b51_row12_col1, #T_94b51_row19_col1 {
#   background-color: #1f78b4;
#   color: #f1f1f1;
# }
# #T_94b51_row12_col2 {
#   background-color: #206eb0;
#   color: #f1f1f1;
# }
# #T_94b51_row13_col1, #T_94b51_row26_col1 {
#   background-color: #1f7ab5;
#   color: #f1f1f1;
# }
# #T_94b51_row13_col2 {
#   background-color: #203089;
#   color: #f1f1f1;
# }
# #T_94b51_row14_col1 {
#   background-color: #2072b1;
#   color: #f1f1f1;
# }
# #T_94b51_row15_col0 {
#   background-color: #253997;
#   color: #f1f1f1;
# }
# #T_94b51_row15_col2 {
#   background-color: #1f7db6;
#   color: #f1f1f1;
# }
# #T_94b51_row16_col1 {
#   background-color: #259ac1;
#   color: #f1f1f1;
# }
# #T_94b51_row16_col2, #T_94b51_row22_col1 {
#   background-color: #253494;
#   color: #f1f1f1;
# }
# #T_94b51_row17_col1 {
#   background-color: #2a9ec1;
#   color: #f1f1f1;
# }
# #T_94b51_row18_col2 {
#   background-color: #1e8bbd;
#   color: #f1f1f1;
# }
# #T_94b51_row18_col3 {
#   background-color: #299dc1;
#   color: #f1f1f1;
# }
# #T_94b51_row19_col2 {
#   background-color: #24409a;
#   color: #f1f1f1;
# }
# #T_94b51_row20_col1 {
#   background-color: #2165ab;
#   color: #f1f1f1;
# }
# #T_94b51_row21_col1 {
#   background-color: #f1faba;
#   color: #000000;
# }
# #T_94b51_row21_col2 {
#   background-color: #1c2d81;
#   color: #f1f1f1;
# }
# #T_94b51_row22_col2 {
#   background-color: #102369;
#   color: #f1f1f1;
# }
# #T_94b51_row23_col1 {
#   background-color: #1a2b7e;
#   color: #f1f1f1;
# }
# #T_94b51_row23_col3 {
#   background-color: #243d98;
#   color: #f1f1f1;
# }
# #T_94b51_row24_col1 {
#   background-color: #37acc3;
#   color: #f1f1f1;
# }
# #T_94b51_row24_col2 {
#   background-color: #233390;
#   color: #f1f1f1;
# }
# #T_94b51_row25_col1 {
#   background-color: #2094c0;
#   color: #f1f1f1;
# }
# #T_94b51_row25_col3 {
#   background-color: #192b7c;
#   color: #f1f1f1;
# }
# #T_94b51_row26_col3 {
#   background-color: #21318d;
#   color: #f1f1f1;
# }
# #T_94b51_row27_col1 {
#   background-color: #e7f6b1;
#   color: #000000;
# }
# #T_94b51_row27_col2 {
#   background-color: #a2dbb8;
#   color: #000000;
# }
# #T_94b51_row28_col2 {
#   background-color: #1f80b8;
#   color: #f1f1f1;
# }
# #T_94b51_row28_col3 {
#   background-color: #2260a9;
#   color: #f1f1f1;
# }
# #T_94b51_row29_col2 {
#   background-color: #216daf;
#   color: #f1f1f1;
# }
# #T_94b51_row29_col3 {
#   background-color: #2ca1c2;
#   color: #f1f1f1;
# }
# #T_94b51_row30_col0 {
#   background-color: #e1f3b2;
#   color: #000000;
# }
# #T_94b51_row31_col1 {
#   background-color: #4cbac2;
#   color: #f1f1f1;
# }
# #T_94b51_row31_col2 {
#   background-color: #2168ad;
#   color: #f1f1f1;
# }
# #T_94b51_row32_col1 {
#   background-color: #234b9f;
#   color: #f1f1f1;
# }
# #T_94b51_row32_col2 {
#   background-color: #2352a3;
#   color: #f1f1f1;
# }
# #T_94b51_row33_col0 {
#   background-color: #90d4b9;
#   color: #000000;
# }
# #T_94b51_row33_col1 {
#   background-color: #6bc6be;
#   color: #000000;
# }
# #T_94b51_row34_col2 {
#   background-color: #32a6c2;
#   color: #f1f1f1;
# }
# #T_94b51_row34_col3 {
#   background-color: #1d2e83;
#   color: #f1f1f1;
# }
# #T_94b51_row35_col1 {
#   background-color: #cdebb4;
#   color: #000000;
# }
# #T_94b51_row35_col2 {
#   background-color: #24489d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_94b51">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >step</th>
#       <th id="T_94b51_level0_col0" class="col_heading level0 col0" >1000</th>
#       <th id="T_94b51_level0_col1" class="col_heading level0 col1" >10000</th>
#       <th id="T_94b51_level0_col2" class="col_heading level0 col2" >50000</th>
#       <th id="T_94b51_level0_col3" class="col_heading level0 col3" >100000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="index_name level1" >task</th>
#       <th class="index_name level2" >shots</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_94b51_level0_row0" class="row_heading level0 row0" rowspan="6">midterm</th>
#       <th id="T_94b51_level1_row0" class="row_heading level1 row0" rowspan="3">nm</th>
#       <th id="T_94b51_level2_row0" class="row_heading level2 row0" >0</th>
#       <td id="T_94b51_row0_col0" class="data row0 col0" >0.4853</td>
#       <td id="T_94b51_row0_col1" class="data row0 col1" >0.4910</td>
#       <td id="T_94b51_row0_col2" class="data row0 col2" >0.4967</td>
#       <td id="T_94b51_row0_col3" class="data row0 col3" >0.4974</td>
#     </tr>
#     <tr>
#       <th id="T_94b51_level2_row1" class="row_heading level2 row1" >3</th>
#       <td id="T_94b51_row1_col0" class="data row1 col0" >0.8828</td>
#       <td id="T_94b51_row1_col1" class="data row1 col1" >0.9129</td>
#       <td id="T_94b51_row1_col2" class="data row1 col2" >0.9160</td>
#       <td id="T_94b51_row1_col3" class="data row1 col
