# %% [markdown]
# # Merged Model Eval - 2026-06-11
#
# Analyze CARC eval results exported from `eval_merged_*_to_*_11_06_2026_*` runs.

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

sns.set_theme(style="whitegrid", context="notebook")

# %%
CSV_PATH = Path("eval_results.csv")
if not CSV_PATH.exists():
    CSV_PATH = Path("scripts/experiments/analysis/archive/eval_merged_11_06_2026/eval_results.csv")
CSV_PATH = CSV_PATH.resolve()

SPLIT = "test"
METRIC = "roc_auc"
METRICS = ["accuracy", "f1", "roc_auc"]

SHOT_ORDER = [0, 3, 10]
DATASET_ORDER = [
    "covid19_twitter",
    "ukr_rus_twitter",
    "midterm",
    "covid_political",
    "election2020",
    "ukr_rus_suspended",
]
TASK_ORDER = ["nm", "lp", "pl"]
TASK_LABELS = {
    "nm": "Neighbor matching",
    "lp": "Temporal link prediction",
    "pl": "Classification",
}
MODEL_ORDER = ["merged_nm", "merged_lp"]
MODEL_LABELS = {
    "merged_nm": "Merged NM",
    "merged_lp": "Merged LP",
}

# %%
df = pd.read_csv(CSV_PATH)

required = {"model", "dataset", "task", "shots", "split", *METRICS}
missing = required - set(df.columns)
if missing:
    raise ValueError(f"CSV is missing required columns: {sorted(missing)}")

df["shots"] = df["shots"].astype(int)
for col in METRICS:
    df[col] = pd.to_numeric(df[col], errors="coerce")

unexpected_models = sorted(set(df["model"]) - set(MODEL_ORDER))
unexpected_shots = sorted(set(df["shots"]) - set(SHOT_ORDER))
unexpected_splits = sorted(set(df["split"]) - {SPLIT})
if unexpected_models:
    raise ValueError(f"Unexpected model values: {unexpected_models}")
if unexpected_shots:
    raise ValueError(f"Unexpected shot values: {unexpected_shots}")
if unexpected_splits:
    raise ValueError(f"Unexpected split values: {unexpected_splits}")

df["dataset"] = pd.Categorical(df["dataset"], categories=DATASET_ORDER, ordered=True)
df["task"] = pd.Categorical(df["task"], categories=TASK_ORDER, ordered=True)
df["model"] = pd.Categorical(df["model"], categories=MODEL_ORDER, ordered=True)
df["model_label"] = df["model"].astype(str).map(MODEL_LABELS)
df["task_label"] = df["task"].astype(str).map(TASK_LABELS)
df = df.sort_values(["split", "dataset", "task", "model", "shots"])

print(f"reading {CSV_PATH}")
print(f"rows: {len(df)}")
display(df.head())
# Out:
# reading /Users/philipp/projects/gfm/prodigy/scripts/experiments/analysis/archive/eval_merged_11_06_2026/eval_results.csv
# rows: 90
#                                              run_name      model checkpoint  \
# 48  eval_merged_nm_to_covid19_twitter_nm_0shot_11_...  merged_nm  merged_nm
# 49  eval_merged_nm_to_covid19_twitter_nm_3shot_11_...  merged_nm  merged_nm
# 50  eval_merged_nm_to_covid19_twitter_nm_10shot_11...  merged_nm  merged_nm
# 3   eval_merged_lp_to_covid19_twitter_nm_0shot_11_...  merged_lp  merged_lp
# 4   eval_merged_lp_to_covid19_twitter_nm_3shot_11_...  merged_lp  merged_lp
#
#             dataset task          task_name  shots            timestamp split  \
# 48  covid19_twitter   nm  neighbor_matching      0  11_06_2026_19_55_11  test
# 49  covid19_twitter   nm  neighbor_matching      3  11_06_2026_19_57_00  test
# 50  covid19_twitter   nm  neighbor_matching     10  11_06_2026_20_07_32  test
# 3   covid19_twitter   nm  neighbor_matching      0  11_06_2026_19_58_24  test
# 4   covid19_twitter   nm  neighbor_matching      3  11_06_2026_19_59_41  test
#
#                                               run_dir  \
# 48  /home1/eibl/gfm/prodigy/log/eval_merged_nm_to_...
# 49  /home1/eibl/gfm/prodigy/log/eval_merged_nm_to_...
# 50  /home1/eibl/gfm/prodigy/log/eval_merged_nm_to_...
# 3   /home1/eibl/gfm/prodigy/log/eval_merged_lp_to_...
# 4   /home1/eibl/gfm/prodigy/log/eval_merged_lp_to_...
#
#                                          metrics_path  accuracy        f1  \
# 48  /home1/eibl/gfm/prodigy/log/eval_merged_nm_to_...  0.335694  0.240232
# 49  /home1/eibl/gfm/prodigy/log/eval_merged_nm_to_...  0.928333  0.928284
# 50  /home1/eibl/gfm/prodigy/log/eval_merged_nm_to_...  0.941306  0.941296
# 3   /home1/eibl/gfm/prodigy/log/eval_merged_lp_to_...  0.331472  0.256269
# 4   /home1/eibl/gfm/prodigy/log/eval_merged_lp_to_...  0.797056  0.797040
#
#      roc_auc model_label         task_label
# 48  0.500624   Merged NM  Neighbor matching
# 49  0.990387   Merged NM  Neighbor matching
# 50  0.993081   Merged NM  Neighbor matching
# 3   0.507582   Merged LP  Neighbor matching
# 4   0.934731   Merged LP  Neighbor matching

# %%
coverage = (
    df.groupby(["model", "dataset", "task"], observed=True)
      .agg(shots=("shots", lambda x: sorted(set(x))), rows=("shots", "size"))
      .reset_index()
      .sort_values(["model", "dataset", "task"])
)

display(coverage)

wide_coverage = (
    df.groupby(["dataset", "task", "shots", "model"], observed=True)
      .size()
      .rename("rows")
      .reset_index()
      .pivot_table(
          index=["dataset", "task", "shots"],
          columns="model",
          values="rows",
          fill_value=0,
          observed=True,
      )
      .reset_index()
      .sort_values(["dataset", "task", "shots"])
)

display(wide_coverage)
# Out:
#         model            dataset task       shots  rows
# 0   merged_nm    covid19_twitter   nm  [0, 3, 10]     3
# 1   merged_nm    covid19_twitter   lp  [0, 3, 10]     3
# 2   merged_nm    covid19_twitter   pl  [0, 3, 10]     3
# 3   merged_nm    ukr_rus_twitter   nm  [0, 3, 10]     3
# 4   merged_nm    ukr_rus_twitter   lp  [0, 3, 10]     3
# 5   merged_nm    ukr_rus_twitter   pl  [0, 3, 10]     3
# 6   merged_nm            midterm   nm  [0, 3, 10]     3
# 7   merged_nm            midterm   lp  [0, 3, 10]     3
# 8   merged_nm            midterm   pl  [0, 3, 10]     3
# 9   merged_nm    covid_political   nm  [0, 3, 10]     3
# 10  merged_nm    covid_political   pl  [0, 3, 10]     3
# 11  merged_nm       election2020   nm  [0, 3, 10]     3
# 12  merged_nm       election2020   pl  [0, 3, 10]     3
# 13  merged_nm  ukr_rus_suspended   nm  [0, 3, 10]     3
# 14  merged_nm  ukr_rus_suspended   pl  [0, 3, 10]     3
# 15  merged_lp    covid19_twitter   nm  [0, 3, 10]     3
# 16  merged_lp    covid19_twitter   lp  [0, 3, 10]     3
# 17  merged_lp    covid19_twitter   pl  [0, 3, 10]     3
# 18  merged_lp    ukr_rus_twitter   nm  [0, 3, 10]     3
# 19  merged_lp    ukr_rus_twitter   lp  [0, 3, 10]     3
# 20  merged_lp    ukr_rus_twitter   pl  [0, 3, 10]     3
# 21  merged_lp            midterm   nm  [0, 3, 10]     3
# 22  merged_lp            midterm   lp  [0, 3, 10]     3
# 23  merged_lp            midterm   pl  [0, 3, 10]     3
# 24  merged_lp    covid_political   nm  [0, 3, 10]     3
# 25  merged_lp    covid_political   pl  [0, 3, 10]     3
# 26  merged_lp       election2020   nm  [0, 3, 10]     3
# 27  merged_lp       election2020   pl  [0, 3, 10]     3
# 28  merged_lp  ukr_rus_suspended   nm  [0, 3, 10]     3
# 29  merged_lp  ukr_rus_suspended   pl  [0, 3, 10]     3
# model            dataset task  shots  merged_nm  merged_lp
# 0        covid19_twitter   nm      0        1.0        1.0
# 1        covid19_twitter   nm      3        1.0        1.0
# 2        covid19_twitter   nm     10        1.0        1.0
# 3        covid19_twitter   lp      0        1.0        1.0
# 4        covid19_twitter   lp      3        1.0        1.0
# 5        covid19_twitter   lp     10        1.0        1.0
# 6        covid19_twitter   pl      0        1.0        1.0
# 7        covid19_twitter   pl      3        1.0        1.0
# 8        covid19_twitter   pl     10        1.0        1.0
# 9        ukr_rus_twitter   nm      0        1.0        1.0
# 10       ukr_rus_twitter   nm      3        1.0        1.0
# 11       ukr_rus_twitter   nm     10        1.0        1.0
# 12       ukr_rus_twitter   lp      0        1.0        1.0
# 13       ukr_rus_twitter   lp      3        1.0        1.0
# 14       ukr_rus_twitter   lp     10        1.0        1.0
# 15       ukr_rus_twitter   pl      0        1.0        1.0
# 16       ukr_rus_twitter   pl      3        1.0        1.0
# 17       ukr_rus_twitter   pl     10        1.0        1.0
# 18               midterm   nm      0        1.0        1.0
# 19               midterm   nm      3        1.0        1.0
# 20               midterm   nm     10        1.0        1.0
# 21               midterm   lp      0        1.0        1.0
# 22               midterm   lp      3        1.0        1.0
# 23               midterm   lp     10        1.0        1.0
# 24               midterm   pl      0        1.0        1.0
# 25               midterm   pl      3        1.0        1.0
# 26               midterm   pl     10        1.0        1.0
# 27       covid_political   nm      0        1.0        1.0
# 28       covid_political   nm      3        1.0        1.0
# 29       covid_political   nm     10        1.0        1.0
# 30       covid_political   pl      0        1.0        1.0
# 31       covid_political   pl      3        1.0        1.0
# 32       covid_political   pl     10        1.0        1.0
# 33          election2020   nm      0        1.0        1.0
# 34          election2020   nm      3        1.0        1.0
# 35          election2020   nm     10        1.0        1.0
# 36          election2020   pl      0        1.0        1.0
# 37          election2020   pl      3        1.0        1.0
# 38          election2020   pl     10        1.0        1.0
# 39     ukr_rus_suspended   nm      0        1.0        1.0
# 40     ukr_rus_suspended   nm      3        1.0        1.0
# 41     ukr_rus_suspended   nm     10        1.0        1.0
# 42     ukr_rus_suspended   pl      0        1.0        1.0
# 43     ukr_rus_suspended   pl      3        1.0        1.0
# 44     ukr_rus_suspended   pl     10        1.0        1.0

# %%
def plot_metric_grid(data, *, split=SPLIT, metric=METRIC, datasets=DATASET_ORDER, tasks=TASK_ORDER):
    subset = data[(data["split"] == split) & data[metric].notna()].copy()
    if subset.empty:
        raise ValueError(f"No rows for split={split!r}, metric={metric!r}")

    palette = dict(zip(MODEL_ORDER, sns.color_palette("Set2", n_colors=len(MODEL_ORDER))))
    fig, axes = plt.subplots(
        nrows=len(datasets),
        ncols=len(tasks),
        figsize=(4.7 * len(tasks), 2.6 * len(datasets)),
        sharex=True,
        sharey=True,
    )

    if len(datasets) == 1 and len(tasks) == 1:
        axes = [[axes]]
    elif len(datasets) == 1:
        axes = [axes]
    elif len(tasks) == 1:
        axes = [[ax] for ax in axes]

    for row_idx, dataset in enumerate(datasets):
        for col_idx, task in enumerate(tasks):
            ax = axes[row_idx][col_idx]
            panel = subset[(subset["dataset"].astype(str) == dataset) & (subset["task"].astype(str) == task)]
            ax.set_title(f"{dataset}\n{TASK_LABELS.get(task, task)}", fontsize=10)

            if panel.empty:
                ax.text(0.5, 0.5, "no data", transform=ax.transAxes, ha="center", va="center", color="0.45")
            else:
                for model in MODEL_ORDER:
                    line = panel[panel["model"].astype(str) == model].sort_values("shots")
                    if line.empty:
                        continue
                    ax.plot(
                        line["shots"],
                        line[metric],
                        marker="o",
                        linewidth=2,
                        markersize=5,
                        color=palette[model],
                        label=MODEL_LABELS.get(model, model),
                    )

            # ax.set_ylim(0, 1.02)
            ax.set_xticks(SHOT_ORDER)
            ax.grid(True, alpha=0.3)
            if row_idx == len(datasets) - 1:
                ax.set_xlabel("shots")
            if col_idx == 0:
                ax.set_ylabel(metric)

    handles, labels = axes[0][0].get_legend_handles_labels()
    if handles:
        fig.legend(handles, labels, title="model", loc="upper center", ncol=len(labels), bbox_to_anchor=(0.5, 1.01))
    fig.suptitle(f"Merged eval results: {split} {metric}", y=1.035, fontsize=14)
    fig.tight_layout()
    return fig

plot_metric_grid(df, metric=METRIC)
plt.show()

# %%
df[df.dataset.eq('covid19_twitter') & df.task.eq('nm') & df.shots.eq(3)]
# Out:
#                                              run_name      model checkpoint  \
# 49  eval_merged_nm_to_covid19_twitter_nm_3shot_11_...  merged_nm  merged_nm
# 4   eval_merged_lp_to_covid19_twitter_nm_3shot_11_...  merged_lp  merged_lp
#
#             dataset task          task_name  shots            timestamp split  \
# 49  covid19_twitter   nm  neighbor_matching      3  11_06_2026_19_57_00  test
# 4   covid19_twitter   nm  neighbor_matching      3  11_06_2026_19_59_41  test
#
#                                               run_dir  \
# 49  /home1/eibl/gfm/prodigy/log/eval_merged_nm_to_...
# 4   /home1/eibl/gfm/prodigy/log/eval_merged_lp_to_...
#
#                                          metrics_path  accuracy        f1  \
# 49  /home1/eibl/gfm/prodigy/log/eval_merged_nm_to_...  0.928333  0.928284
# 4   /home1/eibl/gfm/prodigy/log/eval_merged_lp_to_...  0.797056  0.797040
#
#      roc_auc model_label         task_label
# 49  0.990387   Merged NM  Neighbor matching
# 4   0.934731   Merged LP  Neighbor matching

# %%
for metric in METRICS:
    plot_metric_grid(df, metric=metric)
    plt.show()

# %%
delta = (
    df.pivot_table(
        index=["dataset", "task", "shots"],
        columns="model",
        values=METRICS,
        observed=True,
    )
    .reset_index()
)

for metric in METRICS:
    delta[(metric, "merged_nm_minus_lp")] = delta[(metric, "merged_nm")] - delta[(metric, "merged_lp")]

delta.columns = ["_".join([str(part) for part in col if str(part)]) if isinstance(col, tuple) else col for col in delta.columns]
display(delta.sort_values(["dataset", "task", "shots"]))
# Out:
#               dataset task  shots  accuracy_merged_nm  accuracy_merged_lp  \
# 0     covid19_twitter   nm      0            0.335694            0.331472
# 1     covid19_twitter   nm      3            0.928333            0.797056
# 2     covid19_twitter   nm     10            0.941306            0.801833
# 3     covid19_twitter   lp      0            0.528667            0.649875
# 4     covid19_twitter   lp      3            0.691583            0.653792
# 5     covid19_twitter   lp     10            0.715875            0.579083
# 6     covid19_twitter   pl      0            0.477583            0.553583
# 7     covid19_twitter   pl      3            0.554083            0.530417
# 8     covid19_twitter   pl     10            0.595667            0.547458
# 9     ukr_rus_twitter   nm      0            0.330861            0.335444
# 10    ukr_rus_twitter   nm      3            0.905333            0.784056
# 11    ukr_rus_twitter   nm     10            0.921278            0.793250
# 12    ukr_rus_twitter   lp      0            0.524792            0.670000
# 13    ukr_rus_twitter   lp      3            0.665625            0.630208
# 14    ukr_rus_twitter   lp     10            0.689042            0.566208
# 15    ukr_rus_twitter   pl      0            0.365167            0.493167
# 16    ukr_rus_twitter   pl      3            0.675875            0.522708
# 17    ukr_rus_twitter   pl     10            0.752000            0.533500
# 18            midterm   nm      0            0.338333            0.330639
# 19            midterm   nm      3            0.787972            0.644694
# 20            midterm   nm     10            0.800250            0.644389
# 21            midterm   lp      0            0.538917            0.605333
# 22            midterm   lp      3            0.647333            0.532542
# 23            midterm   lp     10            0.659292            0.510167
# 24            midterm   pl      0            0.500000            0.498958
# 25            midterm   pl      3            0.698708            0.544417
# 26            midterm   pl     10            0.732250            0.565792
# 27    covid_political   nm      0            0.333889            0.338333
# 28    covid_political   nm      3            0.519944            0.379500
# 29    covid_political   nm     10            0.558944            0.388778
# 30    covid_political   pl      0            0.500000            0.503167
# 31    covid_political   pl      3            0.570500            0.530667
# 32    covid_political   pl     10            0.606167            0.534500
# 33       election2020   nm      0            0.332000            0.332000
# 34       election2020   nm      3            0.514667            0.358667
# 35       election2020   nm     10            0.526000            0.360667
# 36       election2020   pl      0            0.500000            0.494000
# 37       election2020   pl      3            0.684000            0.514000
# 38       election2020   pl     10            0.694000            0.519000
# 39  ukr_rus_suspended   nm      0            0.329333            0.336667
# 40  ukr_rus_suspended   nm      3            0.587333            0.453333
# 41  ukr_rus_suspended   nm     10            0.620000            0.470667
# 42  ukr_rus_suspended   pl      0            0.500000            0.467000
# 43  ukr_rus_suspended   pl      3            0.475000            0.502000
# 44  ukr_rus_suspended   pl     10            0.496000            0.483000
#
#     f1_merged_nm  f1_merged_lp  roc_auc_merged_nm  roc_auc_merged_lp  \
# 0       0.240232      0.256269           0.500624           0.507582
# 1       0.928284      0.797040           0.990387           0.934731
# 2       0.941296      0.801815           0.993081           0.939998
# 3       0.591093      0.582044           0.543910           0.721674
# 4       0.739201      0.493385           0.817567           0.844017
# 5       0.764008      0.280382           0.866069           0.861202
# 6       0.643260      0.564719           0.443981           0.587037
# 7       0.553860      0.501460           0.573900           0.542010
# 8       0.585086      0.495424           0.628638           0.563447
# 9       0.210546      0.273097           0.493456           0.505293
# 10      0.905322      0.783987           0.984510           0.931692
# 11      0.921225      0.793241           0.988743           0.938616
# 12      0.626885      0.579350           0.520021           0.745995
# 13      0.721170      0.430761           0.772080           0.799863
# 14      0.745767      0.238572           0.818042           0.818229
# 15      0.533297      0.657256           0.243750           0.510137
# 16      0.691689      0.528737           0.726884           0.530171
# 17      0.774511      0.513894           0.823149           0.545214
# 18      0.245933      0.247664           0.501802           0.501272
# 19      0.786367      0.644710           0.942365           0.844092
# 20      0.798777      0.644382           0.949035           0.845090
# 21      0.647153      0.521374           0.514527           0.663511
# 22      0.713590      0.159940           0.739575           0.664042
# 23      0.731594      0.050711           0.774952           0.704681
# 24      0.000000      0.016842           0.714900           0.576523
# 25      0.686739      0.537792           0.760563           0.559554
# 26      0.719682      0.567360           0.793855           0.591840
# 27      0.168769      0.230413           0.498941           0.506815
# 28      0.516790      0.379371           0.716977           0.558678
# 29      0.550698      0.388431           0.763124           0.565389
# 30      0.000000      0.219020           0.347929           0.497484
# 31      0.595130      0.531370           0.597499           0.544098
# 32      0.631415      0.570638           0.637180           0.547403
# 33      0.166583      0.204630           0.482304           0.490137
# 34      0.506170      0.357027           0.712639           0.534796
# 35      0.518850      0.353514           0.735646           0.537481
# 36      0.000000      0.019380           0.481468           0.400112
# 37      0.690802      0.448980           0.729502           0.528238
# 38      0.670968      0.491005           0.780116           0.535944
# 39      0.167828      0.247641           0.509892           0.506344
# 40      0.581051      0.453240           0.779715           0.638145
# 41      0.607422      0.470791           0.818314           0.654725
# 42      0.666667      0.590315           0.527472           0.470780
# 43      0.493732      0.503984           0.488360           0.510848
# 44      0.493976      0.475127           0.507206           0.480954
#
#     accuracy_merged_nm_minus_lp  f1_merged_nm_minus_lp  \
# 0                      0.004222              -0.016037
# 1                      0.131278               0.131244
# 2                      0.139472               0.139481
# 3                     -0.121208               0.009049
# 4                      0.037792               0.245816
# 5                      0.136792               0.483626
# 6                     -0.076000               0.078540
# 7                      0.023667               0.052400
# 8                      0.048208               0.089662
# 9                     -0.004583              -0.062551
# 10                     0.121278               0.121335
# 11                     0.128028               0.127983
# 12                    -0.145208               0.047535
# 13                     0.035417               0.290409
# 14                     0.122833               0.507195
# 15                    -0.128000              -0.123959
# 16                     0.153167               0.162952
# 17                     0.218500               0.260618
# 18                     0.007694              -0.001731
# 19                     0.143278               0.141657
# 20                     0.155861               0.154395
# 21                    -0.066417               0.125778
# 22                     0.114792               0.553650
# 23                     0.149125               0.680883
# 24                     0.001042              -0.016842
# 25                     0.154292               0.148947
# 26                     0.166458               0.152322
# 27                    -0.004444              -0.061644
# 28                     0.140444               0.137419
# 29                     0.170167               0.162267
# 30                    -0.003167              -0.219020
# 31                     0.039833               0.063760
# 32                     0.071667               0.060777
# 33                     0.000000              -0.038047
# 34                     0.156000               0.149143
# 35                     0.165333               0.165336
# 36                     0.006000              -0.019380
# 37                     0.170000               0.241823
# 38                     0.175000               0.179962
# 39                    -0.007333              -0.079812
# 40                     0.134000               0.127811
# 41                     0.149333               0.136631
# 42                     0.033000               0.076352
# 43                    -0.027000              -0.010252
# 44                     0.013000               0.018849
#
#     roc_auc_merged_nm_minus_lp
# 0                    -0.006958
# 1                     0.055656
# 2                     0.053083
# 3                    -0.177765
# 4                    -0.026450
# 5                     0.004867
# 6                    -0.143055
# 7                     0.031890
# 8                     0.065192
# 9                    -0.011837
# 10                    0.052819
# 11                    0.050127
# 12                   -0.225974
# 13                   -0.027783
# 14                   -0.000188
# 15                   -0.266387
# 16                    0.196712
# 17                    0.277935
# 18                    0.000530
# 19                    0.098272
# 20                    0.103945
# 21                   -0.148984
# 22                    0.075533
# 23                    0.070271
# 24                    0.138377
# 25                    0.201008
# 26                    0.202015
# 27                   -0.007874
# 28                    0.158299
# 29                    0.197735
# 30                   -0.149555
# 31                    0.053400
# 32                    0.089777
# 33                   -0.007833
# 34                    0.177843
# 35                    0.198165
# 36                    0.081356
# 37                    0.201264
# 38                    0.244172
# 39                    0.003548
# 40                    0.141570
# 41                    0.163589
# 42                    0.056692
# 43                   -0.022488
# 44                    0.026252

# %%
delta_metric = f"{METRIC}_merged_nm_minus_lp"
heat = delta.pivot_table(
    index=["dataset", "task"],
    columns="shots",
    values=delta_metric,
    observed=True,
)

fig, ax = plt.subplots(figsize=(7.5, 7.0))
sns.heatmap(heat, annot=True, fmt=".3f", center=0, cmap="vlag", linewidths=0.5, ax=ax)
ax.set_title(f"Delta {METRIC}: Merged NM - Merged LP")
ax.set_xlabel("shots")
ax.set_ylabel("dataset / task")
fig.tight_layout()
plt.show()

# %%
best_rows = []
for metric in METRICS:
    idx = df.groupby(["model", "dataset", "task"], observed=True)[metric].idxmax()
    best = df.loc[idx, ["model_label", "dataset", "task", "shots", metric]].copy()
    best["metric"] = metric
    best = best.rename(columns={metric: "value"})
    best_rows.append(best)

best_table = pd.concat(best_rows, ignore_index=True)
display(best_table[["metric", "model_label", "dataset", "task", "shots", "value"]].sort_values(["metric", "dataset", "task", "model_label"]))
# Out:
#       metric model_label            dataset task  shots     value
# 15  accuracy   Merged LP    covid19_twitter   nm     10  0.801833
# 0   accuracy   Merged NM    covid19_twitter   nm     10  0.941306
# 16  accuracy   Merged LP    covid19_twitter   lp      3  0.653792
# 1   accuracy   Merged NM    covid19_twitter   lp     10  0.715875
# 17  accuracy   Merged LP    covid19_twitter   pl      0  0.553583
# ..       ...         ...                ...  ...    ...       ...
# 72   roc_auc   Merged NM       election2020   pl     10  0.780116
# 88   roc_auc   Merged LP  ukr_rus_suspended   nm     10  0.654725
# 73   roc_auc   Merged NM  ukr_rus_suspended   nm     10  0.818314
# 89   roc_auc   Merged LP  ukr_rus_suspended   pl      3  0.510848
# 74   roc_auc   Merged NM  ukr_rus_suspended   pl      0  0.527472
#
# [90 rows x 6 columns]

# %%
# Optional: save the main figure locally next to the CSV.
FIGURE_DIR = CSV_PATH.parent / "figures"
FIGURE_DIR.mkdir(exist_ok=True)

for metric in METRICS:
    fig = plot_metric_grid(df, metric=metric)
    fig.savefig(FIGURE_DIR / f"eval_merged_11_06_2026_{metric}.png", dpi=200, bbox_inches="tight")
    plt.close(fig)

print(f"wrote figures to {FIGURE_DIR}")
# Out:
# wrote figures to /Users/philipp/projects/gfm/prodigy/scripts/experiments/analysis/archive/eval_merged_11_06_2026/figures

# %%
df[df.shots.eq(3)][['model', 'dataset', 'task', 'roc_auc']].to_csv()
# Out:
# ',model,dataset,task,roc_auc\n49,merged_nm,covid19_twitter,nm,0.990387402199074\n4,merged_lp,covid19_twitter,nm,0.9347313674768518\n46,merged_nm,covid19_twitter,lp,0.8175671527777777\n1,merged_lp,covid19_twitter,lp,0.8440172083333333\n52,merged_nm,covid19_twitter,pl,0.5738999166666666\n7,merged_lp,covid19_twitter,pl,0.5420101284722223\n85,merged_nm,ukr_rus_twitter,nm,0.984510342013889\n40,merged_lp,ukr_rus_twitter,nm,0.9316915306712962\n82,merged_nm,ukr_rus_twitter,lp,0.7720798645833333\n37,merged_lp,ukr_rus_twitter,lp,0.7998632222222223\n88,merged_nm,ukr_rus_twitter,pl,0.72688384375\n43,merged_lp,ukr_rus_twitter,pl,0.5301714895833334\n70,merged_nm,midterm,nm,0.9423645613425924\n25,merged_lp,midterm,nm,0.8440921903935186\n67,merged_nm,midterm,lp,0.7395750138888889\n22,merged_lp,midterm,lp,0.6640420694444444\n73,merged_nm,midterm,pl,0.7605627430555555\n28,merged_lp,midterm,pl,0.5595543125\n55,merged_nm,covid_political,nm,0.7169772777777776\n10,merged_lp,covid_political,nm,0.5586778263888889\n58,merged_nm,covid_political,pl,0.5974988611111111\n13,merged_lp,covid_political,pl,0.5440983750000001\n61,merged_nm,election2020,nm,0.7126389999999999\n16,merged_lp,election2020,nm,0.5347956666666667\n64,merged_nm,election2020,pl,0.729502\n19,merged_lp,election2020,pl,0.528238\n76,merged_nm,ukr_rus_suspended,nm,0.7797153333333333\n31,merged_lp,ukr_rus_suspended,nm,0.6381453333333335\n79,merged_nm,ukr_rus_suspended,pl,0.48836\n34,merged_lp,ukr_rus_suspended,pl,0.510848\n'
